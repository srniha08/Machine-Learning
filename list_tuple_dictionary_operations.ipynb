# %%
# Lists
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)

# Tuples
colors = ("red", "green", "blue")
print(colors[0])

# Dictionaries
person = {"name": "Niha", "age": 21}
print(person["name"])
person["age"] = 22
print(person)
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# red
# Niha
# {'name': 'Niha', 'age': 22}
