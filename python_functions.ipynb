# %%
# Functions in Python

def add(x, y):
    return x + y

def is_even(n):
    return n % 2 == 0

# Using the functions
print("Add:", add(5, 7))
print("Is 10 even?", is_even(10))
# Out:
# Add: 12
# Is 10 even? True
