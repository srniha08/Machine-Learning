# %%
# Variables
a = 10
b = 5
c = a + b
print("Sum:", c)

# String operations
name = "Niha"
greeting = "Assalamualaikum " + name
print(greeting)

# Boolean
is_hungry = True
print("Is hungry?", is_hungry)
# Out:
# Sum: 15
# Assalamualaikum Niha
# Is hungry? True
